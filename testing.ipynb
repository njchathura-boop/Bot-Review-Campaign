# %%
import pandas as pd
df=pd.read_json(r"C:\Users\njcha\Desktop\IITM\SEM3\MLOPS\Bot_Campaign_Project\data\processed\temporal_bundle\campaign_v3\train.jsonl", lines=True)
df.head()
# Out:
#      behavior_profile_version campaign_id category  \
# 0  amazon-behavior-profile-v3        None    Books
# 1  amazon-behavior-profile-v3        None    Books
# 2  amazon-behavior-profile-v3        None    Books
# 3  amazon-behavior-profile-v3        None    Books
# 4  amazon-behavior-profile-v3        None    Books
#
#                      event_role  expected_campaign  generator_seed  \
# 0  controlled_campaign_scenario              False              42
# 1  controlled_campaign_scenario              False              42
# 2  controlled_campaign_scenario              False              42
# 3  controlled_campaign_scenario              False              42
# 4  controlled_campaign_scenario              False              42
#
#    helpful_votes  hours_since_launch  is_pre_launch_review  is_weekend_utc  \
# 0              0            0.626389                 False           False
# 1              0            1.626389                 False           False
# ...

# %%
df['text'].unique(),df.shape
# Out:
# (array(['Delivery was prompt; performance is adequate and one detail could improve.',
#         'Regular use has been dependable, though the controls take time to learn.',
#         'I ordered during the introductory offer and tested it throughout the week.',
#         'The launch discount helped, and the item has performed normally since arrival.',
#         'Purchased after release; setup was straightforward and the result is consistent.',
#         'The item matches the listing and has handled everyday use without trouble.',
#         'Exceptional results and flawless operation make this an essential purchase!',
#         'Brilliant item with unbeatable results, strongly endorsed for every buyer!',
#         'Superb performance and remarkable construction; order this immediately!',
#         'Shockingly poor results and worthless support; avoid at every cost!',
#         'A disastrous purchase that failed completely, do not order it!',
# ...
